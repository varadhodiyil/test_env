# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
import time

# %%
## set random seeds
import numpy as np
np.random.seed(10)

# %%
epochs=100
batch_size = 1000
test_batch_size = 10000
lr = 0.1
momentum = 0.5
log_interval = 50

# %%
kwargs = {'num_workers': 1, 'pin_memory': True}
train_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('../data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.Grayscale(num_output_channels=1),
                       transforms.ToTensor()
                   ])),
    batch_size = batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('../data', train=False, transform=transforms.Compose([
                    transforms.Grayscale(num_output_channels=1),
                    transforms.ToTensor()
                    ])),
    batch_size = test_batch_size, shuffle=True, **kwargs)
# Out:
# Files already downloaded and verified

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 6, kernel_size=5)
        self.conv2 = nn.Conv2d(6, 16, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(16*5*5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 16*5*5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        # x = F.dropout(x, training=self.training)
        return F.log_softmax(x, dim=1)

model = Net()
model.cuda()
# Out:
# Net(
#   (conv1): Conv2d (1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d (6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (conv2_drop): Dropout2d(p=0.5)
#   (fc1): Linear(in_features=400, out_features=120)
#   (fc2): Linear(in_features=120, out_features=84)
#   (fc3): Linear(in_features=84, out_features=10)
# )

# %%
optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)

# %%
import numpy as np
train_losses=np.zeros(epochs)
train_accs=np.zeros(epochs)
test_losses=np.zeros(epochs)
test_accs=np.zeros(epochs)

def train(epochs):
    model.train()
    for epoch in range(1, epochs+1):
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.cuda(), target.cuda()
            data, target = Variable(data), Variable(target)
            optimizer.zero_grad()
            output = model(data)
            loss = F.nll_loss(output, target)
            loss.backward()
            optimizer.step()
            if batch_idx % log_interval == 0:
                correct=0.0
                pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
                correct += pred.eq(target.data.view_as(pred)).long().cpu().sum()
                train_acc= correct / batch_size
                train_loss=loss.data[0]
                print('Train Epoch: {} \tLoss: {:.6f}\tAccuracy:{:.4f}'.format(
                    epoch, train_loss, train_acc))
                test_loss, test_acc = test()
                train_losses[epoch-1] = train_loss
                train_accs[epoch-1] = train_acc
                test_losses[epoch-1] = test_loss
                test_accs[epoch-1] = test_acc

# %%
def test():
    model.eval()
    test_loss = 0
    correct = 0.0
    for data, target in test_loader:
        data, target = data.cuda(), target.cuda()
        data, target = Variable(data, volatile=True), Variable(target)
        output = model(data)
        test_loss += F.nll_loss(output, target, size_average=False).data[0] # sum up batch loss
        pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        correct += pred.eq(target.data.view_as(pred)).long().cpu().sum()
        test_acc= correct / len(test_loader.dataset)

    test_loss /= len(test_loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.4f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        test_acc))
    return(test_loss, test_acc)

# %%
start_time = time.time()
train(epochs)
print("--- Training Time - %s seconds ---" % (time.time() - start_time))
# Out:
# Train Epoch: 1 	Loss: 2.305794	Accuracy:0.1010
#
# Test set: Average loss: 2.3042, Accuracy: 969.0/10000 (0.0969%)
#
# Train Epoch: 2 	Loss: 2.302336	Accuracy:0.0900
#
# Test set: Average loss: 2.3020, Accuracy: 1039.0/10000 (0.1039%)
#
# Train Epoch: 3 	Loss: 2.300783	Accuracy:0.1410
#
# Test set: Average loss: 2.3009, Accuracy: 1051.0/10000 (0.1051%)
#
# Train Epoch: 4 	Loss: 2.296061	Accuracy:0.1640
#
# Test set: Average loss: 2.2966, Accuracy: 1428.0/10000 (0.1428%)
#
# Train Epoch: 5 	Loss: 2.252367	Accuracy:0.1620
#
# Test set: Average loss: 2.2507, Accuracy: 1783.0/10000 (0.1783%)
#
# Train Epoch: 6 	Loss: 2.140454	Accuracy:0.2130
#
# Test set: Average loss: 2.1650, Accuracy: 2040.0/10000 (0.2040%)
#
# Train Epoch: 7 	Loss: 2.014831	Accuracy:0.2620
#
# Test set: Average loss: 2.0249, Accuracy: 2699.0/10000 (0.2699%)
#
# Train Epoch: 8 	Loss: 1.996113	Accuracy:0.2780
#
# Test set: Average loss: 2.0559, Accuracy: 2317.0/10000 (0.2317%)
#
# Train Epoch: 9 	Loss: 1.952708	Accuracy:0.2880
#
# Test set: Average loss: 1.9474, Accuracy: 3032.0/10000 (0.3032%)
#
# Train Epoch: 10 	Loss: 1.965663	Accuracy:0.2880
#
# Test set: Average loss: 1.9243, Accuracy: 3146.0/10000 (0.3146%)
#
# Train Epoch: 11 	Loss: 1.923310	Accuracy:0.3170
#
# Test set: Average loss: 1.8943, Accuracy: 3167.0/10000 (0.3167%)
#
# Train Epoch: 12 	Loss: 1.714635	Accuracy:0.3740
#
# Test set: Average loss: 1.6937, Accuracy: 3960.0/10000 (0.3960%)
#
# Train Epoch: 13 	Loss: 1.656052	Accuracy:0.4130
#
# Test set: Average loss: 1.6670, Accuracy: 4111.0/10000 (0.4111%)
#
# Train Epoch: 14 	Loss: 1.646081	Accuracy:0.4270
#
# Test set: Average loss: 1.7545, Accuracy: 3750.0/10000 (0.3750%)
#
# Train Epoch: 15 	Loss: 1.596936	Accuracy:0.4250
#
# Test set: Average loss: 1.6869, Accuracy: 4002.0/10000 (0.4002%)
#
# Train Epoch: 16 	Loss: 1.523962	Accuracy:0.4610
#
# Test set: Average loss: 1.6196, Accuracy: 4299.0/10000 (0.4299%)
#
# Train Epoch: 17 	Loss: 1.574519	Accuracy:0.4180
#
# Test set: Average loss: 1.6282, Accuracy: 4187.0/10000 (0.4187%)
#
# Train Epoch: 18 	Loss: 1.458038	Accuracy:0.4740
#
# Test set: Average loss: 1.5597, Accuracy: 4490.0/10000 (0.4490%)
#
# Train Epoch: 19 	Loss: 1.531266	Accuracy:0.4430
#
# Test set: Average loss: 1.5888, Accuracy: 4428.0/10000 (0.4428%)
#
# Train Epoch: 20 	Loss: 1.478514	Accuracy:0.4780
#
# Test set: Average loss: 1.5280, Accuracy: 4582.0/10000 (0.4582%)
#
# Train Epoch: 21 	Loss: 1.543853	Accuracy:0.4500
#
# Test set: Average loss: 1.5830, Accuracy: 4448.0/10000 (0.4448%)
#
# Train Epoch: 22 	Loss: 1.444870	Accuracy:0.5130
#
# Test set: Average loss: 1.4954, Accuracy: 4730.0/10000 (0.4730%)
#
# Train Epoch: 23 	Loss: 1.496783	Accuracy:0.4800
#
# Test set: Average loss: 1.5233, Accuracy: 4582.0/10000 (0.4582%)
#
# Train Epoch: 24 	Loss: 1.515460	Accuracy:0.4880
#
# Test set: Average loss: 1.5654, Accuracy: 4482.0/10000 (0.4482%)
#
# Train Epoch: 25 	Loss: 1.424157	Accuracy:0.5000
#
# Test set: Average loss: 1.4712, Accuracy: 4820.0/10000 (0.4820%)
#
# Train Epoch: 26 	Loss: 1.435578	Accuracy:0.5090
#
# Test set: Average loss: 1.4578, Accuracy: 4869.0/10000 (0.4869%)
#
# Train Epoch: 27 	Loss: 1.369130	Accuracy:0.5170
#
# Test set: Average loss: 1.4199, Accuracy: 5031.0/10000 (0.5031%)
#
# Train Epoch: 28 	Loss: 1.330688	Accuracy:0.5270
#
# Test set: Average loss: 1.4572, Accuracy: 4889.0/10000 (0.4889%)
#
# Train Epoch: 29 	Loss: 1.365626	Accuracy:0.5240
#
# Test set: Average loss: 1.4604, Accuracy: 4917.0/10000 (0.4917%)
#
# Train Epoch: 30 	Loss: 1.395560	Accuracy:0.4990
#
# Test set: Average loss: 1.4862, Accuracy: 4784.0/10000 (0.4784%)
#
# Train Epoch: 31 	Loss: 1.325978	Accuracy:0.5280
#
# Test set: Average loss: 1.4243, Accuracy: 4989.0/10000 (0.4989%)
#
# Train Epoch: 32 	Loss: 1.263713	Accuracy:0.5580
#
# Test set: Average loss: 1.3765, Accuracy: 5149.0/10000 (0.5149%)
#
# Train Epoch: 33 	Loss: 1.286899	Accuracy:0.5400
#
# Test set: Average loss: 1.3769, Accuracy: 5166.0/10000 (0.5166%)
#
# Train Epoch: 34 	Loss: 1.365211	Accuracy:0.5150
#
# Test set: Average loss: 1.5474, Accuracy: 4616.0/10000 (0.4616%)
#
# Train Epoch: 35 	Loss: 1.227066	Accuracy:0.5800
#
# Test set: Average loss: 1.3687, Accuracy: 5158.0/10000 (0.5158%)
#
# Train Epoch: 36 	Loss: 1.196205	Accuracy:0.5880
#
# Test set: Average loss: 1.3763, Accuracy: 5192.0/10000 (0.5192%)
#
# Train Epoch: 37 	Loss: 1.271783	Accuracy:0.5650
#
# Test set: Average loss: 1.4334, Accuracy: 4987.0/10000 (0.4987%)
#
# Train Epoch: 38 	Loss: 1.159198	Accuracy:0.5930
#
# Test set: Average loss: 1.3522, Accuracy: 5282.0/10000 (0.5282%)
#
# Train Epoch: 39 	Loss: 1.263231	Accuracy:0.5550
#
# Test set: Average loss: 1.3813, Accuracy: 5150.0/10000 (0.5150%)
#
# Train Epoch: 40 	Loss: 1.133103	Accuracy:0.6030
#
# Test set: Average loss: 1.3715, Accuracy: 5243.0/10000 (0.5243%)
#
# Train Epoch: 41 	Loss: 1.133893	Accuracy:0.6020
#
# Test set: Average loss: 1.4345, Accuracy: 5058.0/10000 (0.5058%)
#
# Train Epoch: 42 	Loss: 1.227987	Accuracy:0.5640
#
# Test set: Average loss: 1.3593, Accuracy: 5329.0/10000 (0.5329%)
#
# Train Epoch: 43 	Loss: 1.047376	Accuracy:0.6430
#
# Test set: Average loss: 1.3339, Accuracy: 5363.0/10000 (0.5363%)
#
# Train Epoch: 44 	Loss: 0.996655	Accuracy:0.6460
#
# Test set: Average loss: 1.3038, Accuracy: 5550.0/10000 (0.5550%)
#
# Train Epoch: 45 	Loss: 1.020657	Accuracy:0.6370
#
# Test set: Average loss: 1.3233, Accuracy: 5436.0/10000 (0.5436%)
#
# Train Epoch: 46 	Loss: 1.010477	Accuracy:0.6470
#
# Test set: Average loss: 1.3498, Accuracy: 5407.0/10000 (0.5407%)
#
# Train Epoch: 47 	Loss: 1.088499	Accuracy:0.6310
#
# Test set: Average loss: 1.3226, Accuracy: 5485.0/10000 (0.5485%)
#
# Train Epoch: 48 	Loss: 1.033772	Accuracy:0.6460
#
# Test set: Average loss: 1.3490, Accuracy: 5427.0/10000 (0.5427%)
#
# Train Epoch: 49 	Loss: 1.005240	Accuracy:0.6380
#
# Test set: Average loss: 1.3392, Accuracy: 5492.0/10000 (0.5492%)
#
# Train Epoch: 50 	Loss: 0.975708	Accuracy:0.6590
#
# Test set: Average loss: 1.2910, Accuracy: 5600.0/10000 (0.5600%)
#
# Train Epoch: 51 	Loss: 0.998257	Accuracy:0.6500
#
# Test set: Average loss: 1.3327, Accuracy: 5515.0/10000 (0.5515%)
#
# Train Epoch: 52 	Loss: 1.130728	Accuracy:0.6060
#
# Test set: Average loss: 1.3342, Accuracy: 5510.0/10000 (0.5510%)
#
# Train Epoch: 53 	Loss: 1.077037	Accuracy:0.6440
#
# Test set: Average loss: 1.4686, Accuracy: 5250.0/10000 (0.5250%)
#
# Train Epoch: 54 	Loss: 1.087332	Accuracy:0.6150
#
# Test set: Average loss: 1.3384, Accuracy: 5382.0/10000 (0.5382%)
#
# Train Epoch: 55 	Loss: 0.952690	Accuracy:0.6760
#
# Test set: Average loss: 1.3119, Accuracy: 5626.0/10000 (0.5626%)
#
# Train Epoch: 56 	Loss: 0.953762	Accuracy:0.6610
#
# Test set: Average loss: 1.3061, Accuracy: 5610.0/10000 (0.5610%)
#
# Train Epoch: 57 	Loss: 0.978024	Accuracy:0.6550
#
# Test set: Average loss: 1.3097, Accuracy: 5626.0/10000 (0.5626%)
#
# Train Epoch: 58 	Loss: 0.843044	Accuracy:0.7030
#
# Test set: Average loss: 1.3285, Accuracy: 5596.0/10000 (0.5596%)
#
# Train Epoch: 59 	Loss: 0.888561	Accuracy:0.6980
#
# Test set: Average loss: 1.3783, Accuracy: 5522.0/10000 (0.5522%)
#
# Train Epoch: 60 	Loss: 0.973070	Accuracy:0.6470
#
# Test set: Average loss: 1.4148, Accuracy: 5328.0/10000 (0.5328%)
#
# Train Epoch: 61 	Loss: 0.823150	Accuracy:0.7020
#
# Test set: Average loss: 1.3728, Accuracy: 5570.0/10000 (0.5570%)
#
# Train Epoch: 62 	Loss: 0.811434	Accuracy:0.7170
#
# Test set: Average loss: 1.3545, Accuracy: 5598.0/10000 (0.5598%)
#
# Train Epoch: 63 	Loss: 0.878067	Accuracy:0.7110
#
# Test set: Average loss: 1.4438, Accuracy: 5452.0/10000 (0.5452%)
#
# Train Epoch: 64 	Loss: 0.793232	Accuracy:0.7210
#
# Test set: Average loss: 1.3414, Accuracy: 5624.0/10000 (0.5624%)
#
# Train Epoch: 65 	Loss: 0.833801	Accuracy:0.7050
#
# Test set: Average loss: 1.3256, Accuracy: 5733.0/10000 (0.5733%)
#
# Train Epoch: 66 	Loss: 0.860777	Accuracy:0.6930
#
# Test set: Average loss: 1.3898, Accuracy: 5556.0/10000 (0.5556%)
#
# Train Epoch: 67 	Loss: 0.795322	Accuracy:0.7120
#
# Test set: Average loss: 1.3282, Accuracy: 5678.0/10000 (0.5678%)
#
# Train Epoch: 68 	Loss: 0.783077	Accuracy:0.7140
#
# Test set: Average loss: 1.3400, Accuracy: 5615.0/10000 (0.5615%)
#
# Train Epoch: 69 	Loss: 0.670429	Accuracy:0.7670
#
# Test set: Average loss: 1.3822, Accuracy: 5636.0/10000 (0.5636%)
#
# Train Epoch: 70 	Loss: 0.833395	Accuracy:0.7090
#
# Test set: Average loss: 1.4399, Accuracy: 5543.0/10000 (0.5543%)
#
# Train Epoch: 71 	Loss: 0.786518	Accuracy:0.7200
#
# Test set: Average loss: 1.3948, Accuracy: 5605.0/10000 (0.5605%)
#
# Train Epoch: 72 	Loss: 0.766595	Accuracy:0.7290
# Test set: Average loss: 1.4807, Accuracy: 5474.0/10000 (0.5474%)
#
# Train Epoch: 73 	Loss: 0.711679	Accuracy:0.7480
#
# Test set: Average loss: 1.3980, Accuracy: 5630.0/10000 (0.5630%)
#
# Train Epoch: 74 	Loss: 0.661279	Accuracy:0.7820
#
# Test set: Average loss: 1.3866, Accuracy: 5721.0/10000 (0.5721%)
#
# Train Epoch: 75 	Loss: 0.654456	Accuracy:0.7780
#
# Test set: Average loss: 1.4016, Accuracy: 5668.0/10000 (0.5668%)
#
# Train Epoch: 76 	Loss: 0.718605	Accuracy:0.7480
#
# Test set: Average loss: 1.4371, Accuracy: 5588.0/10000 (0.5588%)
#
# Train Epoch: 77 	Loss: 0.619930	Accuracy:0.7880
#
# Test set: Average loss: 1.4294, Accuracy: 5675.0/10000 (0.5675%)
#
# Train Epoch: 78 	Loss: 0.650370	Accuracy:0.7720
#
# Test set: Average loss: 1.4685, Accuracy: 5587.0/10000 (0.5587%)
#
# Train Epoch: 79 	Loss: 0.701731	Accuracy:0.7620
#
# Test set: Average loss: 1.5273, Accuracy: 5472.0/10000 (0.5472%)
#
# Train Epoch: 80 	Loss: 0.631484	Accuracy:0.7720
#
# Test set: Average loss: 1.4831, Accuracy: 5625.0/10000 (0.5625%)
#
# Train Epoch: 81 	Loss: 0.647879	Accuracy:0.7680
#
# Test set: Average loss: 1.4523, Accuracy: 5708.0/10000 (0.5708%)
#
# Train Epoch: 82 	Loss: 0.620718	Accuracy:0.7840
#
# Test set: Average loss: 1.5226, Accuracy: 5507.0/10000 (0.5507%)
#
# Train Epoch: 83 	Loss: 0.646782	Accuracy:0.7670
#
# Test set: Average loss: 1.5207, Accuracy: 5511.0/10000 (0.5511%)
#
# Train Epoch: 84 	Loss: 0.737141	Accuracy:0.7630
#
# Test set: Average loss: 1.4344, Accuracy: 5558.0/10000 (0.5558%)
#
# Train Epoch: 85 	Loss: 0.624150	Accuracy:0.7890
#
# Test set: Average loss: 1.5564, Accuracy: 5608.0/10000 (0.5608%)
#
# Train Epoch: 86 	Loss: 0.839498	Accuracy:0.6890
#
# Test set: Average loss: 1.6612, Accuracy: 5338.0/10000 (0.5338%)
#
# Train Epoch: 87 	Loss: 0.593371	Accuracy:0.8070
#
# Test set: Average loss: 1.5914, Accuracy: 5580.0/10000 (0.5580%)
#
# Train Epoch: 88 	Loss: 0.569500	Accuracy:0.8000
#
# Test set: Average loss: 1.5539, Accuracy: 5615.0/10000 (0.5615%)
#
# Train Epoch: 89 	Loss: 0.583926	Accuracy:0.8040
#
# Test set: Average loss: 1.5268, Accuracy: 5612.0/10000 (0.5612%)
#
# Train Epoch: 90 	Loss: 0.693413	Accuracy:0.7630
#
# Test set: Average loss: 1.6505, Accuracy: 5489.0/10000 (0.5489%)
#
# Train Epoch: 91 	Loss: 0.656823	Accuracy:0.7610
#
# Test set: Average loss: 1.7965, Accuracy: 5303.0/10000 (0.5303%)
#
# Train Epoch: 92 	Loss: 0.577732	Accuracy:0.8000
#
# Test set: Average loss: 1.6697, Accuracy: 5526.0/10000 (0.5526%)
#
# Train Epoch: 93 	Loss: 0.560336	Accuracy:0.8050
#
# Test set: Average loss: 1.5962, Accuracy: 5609.0/10000 (0.5609%)
#
# Train Epoch: 94 	Loss: 0.760103	Accuracy:0.7360
#
# Test set: Average loss: 1.6661, Accuracy: 5299.0/10000 (0.5299%)
#
# Train Epoch: 95 	Loss: 0.593525	Accuracy:0.7970
#
# Test set: Average loss: 1.6564, Accuracy: 5448.0/10000 (0.5448%)
#
# Train Epoch: 96 	Loss: 0.628444	Accuracy:0.7690
#
# Test set: Average loss: 1.7146, Accuracy: 5355.0/10000 (0.5355%)
#
# Train Epoch: 97 	Loss: 0.550085	Accuracy:0.8100
#
# Test set: Average loss: 1.6445, Accuracy: 5588.0/10000 (0.5588%)
#
# Train Epoch: 98 	Loss: 0.504052	Accuracy:0.8260
#
# Test set: Average loss: 1.6886, Accuracy: 5537.0/10000 (0.5537%)
#
# Train Epoch: 99 	Loss: 0.501177	Accuracy:0.8220
#
# Test set: Average loss: 1.7347, Accuracy: 5567.0/10000 (0.5567%)
#
# Train Epoch: 100 	Loss: 0.480015	Accuracy:0.8290
#
# Test set: Average loss: 1.6723, Accuracy: 5524.0/10000 (0.5524%)
#
# --- Training Time - 436.723762035 seconds ---

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.ndimage.filters import gaussian_filter1d

test_acc_smooth = gaussian_filter1d(test_accs, sigma=0.5)
train_loss_smooth = gaussian_filter1d(train_losses, sigma=1)
_, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(range(epochs), train_loss_smooth)
ax2.plot(range(len(test_acc_smooth)), test_acc_smooth, 'r')
ax1.set_xlabel('epoch')
ax1.set_ylabel('train loss')
ax2.set_ylabel('test accuracy')
ax2.set_title('Test Accuracy: {:.2f}'.format(test_accs[-1]))
# Out:
# Text(0.5,1,'Test Accuracy: 0.55')
